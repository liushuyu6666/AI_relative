# %% [markdown]
# ## R Magic

# %%
# activate R magic
# %load_ext rpy2.ipython
# Out:
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# /usr/local/lib/python3.6/dist-packages/rpy2/robjects/pandas2ri.py:34: UserWarning: pandas >= 1.0 is not supported.
#   warnings.warn('pandas >= 1.0 is not supported.')

# %% [markdown]
# ## install packages

# %%
# %%R
# install.packages("XML")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/XML_3.99-0.5.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 968563 bytes (945 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(XML)
# Out:
# R[write to console]:
# Attaching package: ‘XML’
#
#
# R[write to console]: The following object is masked from ‘package:tools’:
#
#     toHTML

# %%
# %%R
# install.packages("methods")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# %%R
# library(methods)

# %%
# %%R
# install.packages("httr")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/httr_1.4.2.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 159950 bytes (156 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(httr)

# %% [markdown]
# ## read .xml

# %%
# %cd /content/drive/My Drive/Colab Notebooks/AI_relative/
# !ls
# %cd Data_mining_in_R/
# !ls
# %cd age_of_empire_III/
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/AI_relative
# algorithm_explore  deep_learning_GAN  NLP_tutorial	 pytorch_study
# Data_mining_in_R   GAN_sad.ipynb      push_to_git.ipynb
# /content/drive/My Drive/Colab Notebooks/AI_relative/Data_mining_in_R
# age_of_empire_III  tutorial
# /content/drive/My Drive/Colab Notebooks/AI_relative/Data_mining_in_R/age_of_empire_III
# age_of_empire_1.xml  project_age_of_empire_III.ipynb

# %%
# %%R
# raw_data <- xmlParse(file = "age_of_empire_1.xml")
# raw_data
# Out:
# Streaming output truncated to the last 5000 lines.
#     <UnitType>AbstractMine</UnitType>
#     <UnitType>HasBountyValue</UnitType>
#     <UnitType>NatureClass</UnitType>
#     <Flag>StartsAtFullEfficiency</Flag>
#     <Flag>Immoveable</Flag>
#     <Flag>NoBloodOnDeath</Flag>
#     <Flag>ObscuresUnits</Flag>
#     <Flag>NonAutoFormedUnit</Flag>
#     <Flag>Doppled</Flag>
#     <Flag>SelectWithObstruction</Flag>
#     <Flag>PaintTextureWhenPlacing</Flag>
#     <Flag>DoNotDieAtZeroHitpoints</Flag>
#     <Flag>DieAtZeroResources</Flag>
#     <Flag>DoNotValidateResourceInventory</Flag>
#     <Flag>NoHPBar</Flag>
#     <Flag>Invulnerable</Flag>
#     <Flag>ForceToGaia</Flag>
#     <Flag>DontRotateObstruction</Flag>
#     <Flag>FlattenGround</Flag>
#     <Flag>Tracked</Flag>
#     <Command page="10" column="2">Delete</Command>
#   </Unit>
#   <Unit id="540" name="SPCMineProps">
#     <DBID>898</DBID>
#     <DisplayNameID>34913</DisplayNameID>
#     <EditorNameID>34914</EditorNameID>
# ...

# %%
# %%R
# root <- xmlRoot(raw_data)
# print(root[1])
# print(rootsize <- xmlSize(root))
# print(root[[1]])
# Out:
# $Unit
# <Unit id="0" name="InvisibleProjectile">
#   <DBID>20</DBID>
#   <DisplayNameID>22885</DisplayNameID>
#   <EditorNameID>22890</EditorNameID>
#   <ObstructionRadiusX>0.1000</ObstructionRadiusX>
#   <ObstructionRadiusZ>0.1000</ObstructionRadiusZ>
#   <MaxVelocity>60.0000</MaxVelocity>
#   <MovementType>air</MovementType>
#   <AnimFile>effects\projectiles\musket_ball.xml</AnimFile>
#   <Lifespan>2.0000</Lifespan>
#   <LOS>0.0000</LOS>
#   <UnitType>EmbellishmentClass</UnitType>
#   <UnitType>Projectile</UnitType>
#   <Flag>NoIdleActions</Flag>
#   <Flag>NonCollideable</Flag>
#   <Flag>DestroyProjectile</Flag>
#   <Flag>DoNotCreateUnitGroupAutomatically</Flag>
#   <Flag>NoBloodOnDeath</Flag>
#   <Flag>NotSearchable</Flag>
#   <Flag>Projectile</Flag>
#   <Flag>NoTieToGround</Flag>
#   <Flag>DoNotShowOnMiniMap</Flag>
#   <Flag>NotSelectable</Flag>
#   <Flag>DoNotDieAtZeroHitpoints</Flag>
#   <Flag>NoHPBar</Flag>
#   <Flag>NonAutoFormedUnit</Flag>
# ...

# %% [markdown]
# ## initial analysis

# %%
# %%R
# for (item in root){
#
# }
